# %%
from cdapython import Q, columns,unique_terms


# cptacsubjectquery = Q('subject_associated_project = "%cptac%"')
# df = cptacsubjectquery.subject.count.run(
#     include=("specimen_id specimen_type specimen_Files")
# ).to_dataframe()


# df
Q.get_version()
# Out:
# '2022.9.27'

# %%
# col,val = "Column_Name:specimen_Files".split(":")
# df = columns().to_dataframe()
# df[df[col].str.contains(val, case=False, na=False)]
""" to search with to_dataframe function you need the column name and the value use : to search like this Description:GDC """
columns().to_dataframe(include="Description:GDC")
# Out:
#                   Column_Name  \
# 40                 GDC_FILTER
# 41      GDC_Validation_Status
# 54   Matched_Norm_Sample_UUID
# 78          Tumor_Sample_UUID
# 92            anatomical_site
# 97                    case_id
# 119                  fileUUID
# 133           normal_bam_uuid
# 149                   species
# 156                src_vcf_id
# 175            tumor_bam_uuid
#
#                                            Description
# 40     GDC filters applied universally across all MAFs
# 41   GDC implementation of validation checks. See n...
# 54   Unique GDC identifier for normal aliquot (1018...
# 78   Unique GDC identifier for tumor aliquot (10189...
# 92   Per GDC Dictionary, the text term that represe...
# 97       Unique GDC identifier for the underlying case
# 119  |-delimited list of unique GDC identifiers for...
# 133  Unique GDC identifier for the underlying norma...
# 149  The taxonomic group (e.g. species) of the pati...
# 156       |-delimited list of GDC VCF file identifiers
# 175  Unique GDC identifier for the underlying bam file

# %%
unique_terms("GDC_FILTER").to_dataframe(include="GDC_FILTER:NonExonic;bitgt")
# Out:
#                                            GDC_FILTER
# 1                                     NonExonic;bitgt
# 2                      NonExonic;bitgt;common_in_exac
# 3              NonExonic;bitgt;common_in_exac;gdc_pon
# 4     NonExonic;bitgt;common_in_exac;gdc_pon;wga_pair
# 5             NonExonic;bitgt;common_in_exac;wga_pair
# 6                             NonExonic;bitgt;gdc_pon
# 7                  NonExonic;bitgt;gdc_pon;wga_normal
# 8                    NonExonic;bitgt;gdc_pon;wga_pair
# 9                                 NonExonic;bitgt;ndp
# 10                       NonExonic;bitgt;ndp;wga_pair
# 11  NonExonic;bitgt;ndp;wga_pair|NonExonic;bitgt;w...
# 12                         NonExonic;bitgt;wga_normal
# 13                           NonExonic;bitgt;wga_pair
# 14                          NonExonic;bitgt;wga_tumor

# %%
Q("GDC_FILTER = 'NonExonic;bitgt'").mutation.run().to_dataframe(include="case_barcode:TCGA-JL-")
# Out:
# Getting results from database
#                         Total execution time: 0
#                         min 3.688 sec 3688 ms
#    project_short_name  case_barcode sample_barcode_tumor  \
# 96          TCGA-BRCA  TCGA-JL-A3YX     TCGA-JL-A3YX-01A
#
#    sample_barcode_normal         aliquot_barcode_tumor  \
# 96      TCGA-JL-A3YX-10A  TCGA-JL-A3YX-01A-11D-A22X-09
#
#           aliquot_barcode_normal Hugo_Symbol  Entrez_Gene_Id Center  \
# 96  TCGA-JL-A3YX-10A-01D-A22X-09       BLVRA             644  WUGSC
#
#    NCBI_Build  ...                        tumor_bam_uuid  \
# 96     GRCh38  ...  8e7c8c6a-e9ee-48cf-b919-e5bfa3e16f5c
#
#                          normal_bam_uuid  \
# 96  b84f50ba-929d-4a86-8d52-ccdde2460fcb
#
#                                  case_id       GDC_FILTER COSMIC MC3_Overlap  \
# 96  75f6e476-233a-409c-a3ef-0240be569813  NonExonic;bitgt   None        True
#
#    GDC_Validation_Status                         callerName  \
# 96               Unknown  muse|mutect|somaticsniper|varscan
#
#                                              fileUUID  \
# 96  b8ca5856-9819-459c-87c5-94e91aca4032|995c0111-...
#
#                                              fileName
# 96  TCGA.BRCA.muse.b8ca5856-9819-459c-87c5-94e91ac...
#
# [1 rows x 109 columns]

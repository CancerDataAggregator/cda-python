# %%
from cdapython import Q
from global_settings import integration_host, integration_table

a = (
    Q("subject_identifier_system = 'GDC'")
    .ORDER_BY("days_to_birth:-1")
    .subject.run(show_sql=True, host=integration_host, table=integration_table)
    .to_dataframe()
)
a
# Out:
# Getting results from database
#                         Total execution time: 0
#                         min 3.727 sec 3727 ms
#                 subject_id                                 subject_identifier  \
# 0                C3N-03092  [{'system': 'GDC', 'value': 'C3N-03092'}, {'sy...
# 1                C3N-02252  [{'system': 'GDC', 'value': 'C3N-02252'}, {'sy...
# 2                C3N-03093  [{'system': 'GDC', 'value': 'C3N-03093'}, {'sy...
# 3   TARGET-15-SJMPAL043774  [{'system': 'GDC', 'value': 'TARGET-15-SJMPAL0...
# 4   TARGET-15-SJMPAL044950  [{'system': 'GDC', 'value': 'TARGET-15-SJMPAL0...
# ..                     ...                                                ...
# 95           MP2PRT-PAWPXB      [{'system': 'GDC', 'value': 'MP2PRT-PAWPXB'}]
# 96        TARGET-10-PAPKNJ   [{'system': 'GDC', 'value': 'TARGET-10-PAPKNJ'}]
# 97       BLGSP-71-08-00205  [{'system': 'GDC', 'value': 'BLGSP-71-08-00205'}]
# 98       BLGSP-71-19-00122  [{'system': 'GDC', 'value': 'BLGSP-71-19-00122'}]
# 99           MP2PRT-PAYXAD      [{'system': 'GDC', 'value': 'MP2PRT-PAYXAD'}]
#
#          species     sex                       race               ethnicity  \
# 0   homo sapiens    male               not reported            not reported
# 1   homo sapiens  female                      white  not hispanic or latino
# 2   homo sapiens  female               not reported            not reported
# 3   homo sapiens    male                    Unknown                 Unknown
# 4   homo sapiens    male                    Unknown                 Unknown
# ..           ...     ...                        ...                     ...
# 95  homo sapiens    male                      white  not hispanic or latino
# 96  homo sapiens  female                      white  not hispanic or latino
# 97  homo sapiens    male  black or african american  not hispanic or latino
# 98  homo sapiens  female                      white                 Unknown
# 99  homo sapiens  female                      white  not hispanic or latino
#
#     days_to_birth               subject_associated_project  vital_status  \
# 0               0  [CPTAC-3, cptac_lscc, CPTAC3-Discovery]  Not Reported
# 1               0  [CPTAC-3, cptac_lscc, CPTAC3-Discovery]  Not Reported
# 2               0  [CPTAC-3, cptac_lscc, CPTAC3-Discovery]  Not Reported
# 3             -12                          [TARGET-ALL-P3]          Dead
# 4             -41                          [TARGET-ALL-P3]          Dead
# ..            ...                                      ...           ...
# 95          -1576                              [MP2PRT-WT]          Dead
# 96          -1577                          [TARGET-ALL-P2]         Alive
# 97          -1586                             [CGCI-BLGSP]         Alive
# 98          -1593                             [CGCI-BLGSP]         Alive
# 99          -1604                              [MP2PRT-WT]          Dead
#
#     days_to_death cause_of_death
# 0             NaN           None
# 1             NaN           None
# 2             NaN           None
# 3           156.0           None
# 4           301.0           None
# ..            ...            ...
# 95          343.0           None
# 96            NaN           None
# 97            NaN           None
# 98            NaN           None
# 99          752.0           None
#
# [100 rows x 11 columns]

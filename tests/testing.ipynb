# %%
from cdapython import Q
from global_settings import integration_host, integration_table

a = (
    Q("subject_identifier_system = 'GDC'")
    .ORDER_BY("days_to_birth:-1")
    .subject.run(show_sql=True, host=integration_host, table=integration_table)
    .to_dataframe()
)
a
# Out:
# Getting results from database
#       subject_id                                 subject_identifier  \
# 0      C3N-03093  [{'system': 'GDC', 'value': 'C3N-03093'}, {'sy...
# 1      C3N-03092  [{'system': 'GDC', 'value': 'C3N-03092'}, {'sy...
# 2      C3N-02252  [{'system': 'GDC', 'value': 'C3N-02252'}, {'sy...
# 3      C3N-02714  [{'system': 'GDC', 'value': 'C3N-02714'}, {'sy...
# 4      C3N-02783  [{'system': 'GDC', 'value': 'C3N-02783'}, {'sy...
# ..           ...                                                ...
# 95  TCGA-A2-A0EX  [{'system': 'GDC', 'value': 'TCGA-A2-A0EX'}, {...
# 96     C3L-00161  [{'system': 'GDC', 'value': 'C3L-00161'}, {'sy...
# 97     C3N-00244  [{'system': 'GDC', 'value': 'C3N-00244'}, {'sy...
# 98  TCGA-AA-A010  [{'system': 'GDC', 'value': 'TCGA-AA-A010'}, {...
# 99     C3N-02000  [{'system': 'GDC', 'value': 'C3N-02000'}, {'sy...
#
#          species     sex          race               ethnicity  days_to_birth  \
# 0   homo sapiens  female  not reported            not reported              0
# 1   homo sapiens    male  not reported            not reported              0
# 2   homo sapiens  female         white  not hispanic or latino              0
# 3   homo sapiens    male  not reported            not reported          -8551
# 4   homo sapiens  female  not reported            not reported          -8889
# ..           ...     ...           ...                     ...            ...
# 95  homo sapiens  female         white  not hispanic or latino         -16858
# 96  homo sapiens  female         white      hispanic or latino         -16864
# 97  homo sapiens    male         white  not hispanic or latino         -16873
# 98  homo sapiens  female  not reported            not reported         -16922
# 99  homo sapiens  female  not reported            not reported         -16924
#
#                   subject_associated_project  vital_status  days_to_death  \
# 0    [CPTAC-3, cptac_lscc, CPTAC3-Discovery]  Not Reported            NaN
# 1    [CPTAC-3, cptac_lscc, CPTAC3-Discovery]  Not Reported            NaN
# 2    [CPTAC-3, cptac_lscc, CPTAC3-Discovery]  Not Reported            NaN
# 3   [cptac_hnscc, CPTAC-3, CPTAC3-Discovery]         Alive            NaN
# 4     [cptac_gbm, CPTAC-3, CPTAC3-Discovery]         Alive            NaN
# ..                                       ...           ...            ...
# 95        [tcga_brca, CPTAC-TCGA, TCGA-BRCA]         Alive            NaN
# 96   [CPTAC-3, cptac_ucec, CPTAC3-Discovery]         Alive            NaN
# 97  [cptac_ccrcc, CPTAC-3, CPTAC3-Discovery]         Alive            NaN
# 98        [TCGA-COAD, CPTAC-TCGA, tcga_coad]         Alive            NaN
# 99   [cptac_luad, CPTAC-3, CPTAC3-Discovery]         Alive            NaN
#
#    cause_of_death
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# ..            ...
# 95           None
# 96   Not Reported
# 97   Not Reported
# 98           None
# 99           None
#
# [100 rows x 11 columns]

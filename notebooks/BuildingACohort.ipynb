# %% [markdown]
# # Cohort Building

# %% [markdown]
# **Example use case:**
#
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" alt="alt_text" align="left"
# 	width="150" height="150" />
# Julia is an oncologist that specializes in female reproductive health. As part of her research, she is interested in  using existing data on uterine cancers. If possible, she would like to see multiple datatypes (gross imaging, genomic data, proteomic data, histology) that come from the same patient, so she can look for shared phenotypes to test for their potential as early diagnostics. Julia heard that the Cancer Data Aggregator has made it easy to search across multiple datasets created by NCI, and so has decided to start her search there.

# %% [markdown]
# ## Getting Started
#
# The CDA provides a custom python tool for searching CDA data. [`Q`](usage/#q) (short for Query) offers several ways to search and filter data, and several input modes:
#
# ---
# - **<a href="../../QuickStart/usage/#q">Q.()</a>** builds a query that can be used by `run()` or `count()`
# - **<a href="../../QuickStart/usage/#qrun">Q.run()</a>** returns data for the specified search
# - **<a href="../../QuickStart/usage/#qcount">Q.count()</a>** returns summary information (counts) data that fit the specified search
# - **<a href="../../QuickStart/usage/#columns">columns()</a>** returns entity field names
# - **<a href="../../QuickStart/usage/#unique_terms">unique_terms()</a>** returns entity field contents
#
# ---
#
# Before Julia does any work, she needs to import these functions cdapython.
# She'll also need to import [pandas](https://pandas.pydata.org/) to get nice dataframes.
# Finally, she tells cdapython to report it's version so she can be sure she's using the one she means to:

# %%
from cdapython import Q, columns, unique_terms, query
import cdapython
import pandas as pd 
print(cdapython.__version__)
# Out:
# 2022.6.28

# %%
Q.set_default_project_dataset("broad-dsde-dev.cda_dev")
Q.set_host_url("https://cancerdata.dsde-dev.broadinstitute.org/")
Q.get_host_url()
# Out:
# 'https://cancerdata.dsde-dev.broadinstitute.org/'

# %%
Q.get_default_project_dataset()
# Out:
# 'broad-dsde-dev.cda_dev'

# %% [markdown]
# <div class="cdanote" style="background-color:#b3e5d5;color:black;padding:20px;">
#
#
# CDA data comes from three sources:
# <ul>
# <li><b>The <a href="https://proteomic.datacommons.cancer.gov/pdc/"> Proteomic Data Commons</a> (PDC)</b></li>
# <li><b>The <a href="https://gdc.cancer.gov/">Genomic Data Commons</a> (GDC)</b></li>
# <li><b>The <a href="https://datacommons.cancer.gov/repository/imaging-data-commons">Imaging Data Commons</a> (IDC)</b></li>
# </ul>
#
# The CDA makes this data searchable in four main endpoints:
#
# <ul>
# <li><b>subject:</b> A patient entity captures the study-independent metadata for research subjects. Human research subjects are usually not traceable to a particular person to protect the subjects privacy.</li>
# <li><b>researchsubject:</b> A research subject is the entity of interest in a specific research study or project, typically a human being or an animal, but can also be a device, group of humans or animals, or a tissue sample. Human research subjects are usually not traceable to a particular person to protect the subjects privacy. This entity plays the role of the case_id in existing data. An individual who participates in 3 studies will have 3 researchsubject IDs</li>
# <li><b>specimen:</b> Any material taken as a sample from a biological entity (living or dead), or from a physical object or the environment. Specimens are usually collected as an example of their kind, often for use in some investigation.</li>
# <li><b>file:</b> A unit of data about subjects, researchsubjects, specimens, or their associated information</li>
# </ul>
# and two endpoints that offer deeper information about data in the researchsubject endpoint:
# <ul>
# <li><b>diagnosis:</b> A collection of characteristics that describe an abnormal condition of the body as assessed at a point in time. May be used to capture information about neoplastic and non-neoplastic conditions.</li>
# <li><b>treatment:</b> Represent medication administration or other treatment types.</li>
# </ul>
# Any metadata field can be searched from any endpoint, the only difference between search types is what type of data is returned by default. This means that you can think of the CDA as a really, really enormous spreadsheet full of data. To search this enormous spreadsheet, you'd want select columns, and then filter rows.
# </div>

# %% [markdown]
# ## Finding Search Terms
#
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
#
#    Accordingly, to see what search fields are available, Julia starts by using the command `columns`:

# %%
columns().to_list()
# Out:
# ['File.id',
#  'File.identifier.system',
#  'File.identifier.value',
#  'File.label',
#  'File.data_category',
#  'File.data_type',
#  'File.file_format',
#  'File.associated_project',
#  'File.drs_uri',
#  'File.byte_size',
#  'File.checksum',
#  'File.data_modality',
#  'File.imaging_modality',
#  'File.dbgap_accession_number',
#  'File.imaging_series',
#  'id',
#  'identifier.system',
#  'identifier.value',
#  'species',
#  'sex',
#  'race',
#  'ethnicity',
#  'days_to_birth',
#  'subject_associated_project',
#  'vital_status',
#  'days_to_death',
#  'cause_of_death',
#  'ResearchSubject.id',
#  'ResearchSubject.identifier.system',
#  'ResearchSubject.identifier.value',
#  'ResearchSubject.member_of_research_project',
#  'ResearchSubject.primary_diagnosis_condition',
#  'ResearchSubject.primary_diagnosis_site',
#  'ResearchSubject.Diagnosis.id',
#  'ResearchSubject.Diagnosis.identifier.system',
#  'ResearchSubject.Diagnosis.identifier.value',
#  'ResearchSubject.Diagnosis.primary_diagnosis',
#  'ResearchSubject.Diagnosis.age_at_diagnosis',
#  'ResearchSubject.Diagnosis.morphology',
#  'ResearchSubject.Diagnosis.stage',
#  'ResearchSubject.Diagnosis.grade',
#  'ResearchSubject.Diagnosis.method_of_diagnosis',
#  'ResearchSubject.Diagnosis.Treatment.id',
#  'ResearchSubject.Diagnosis.Treatment.identifier.system',
#  'ResearchSubject.Diagnosis.Treatment.identifier.value',
#  'ResearchSubject.Diagnosis.Treatment.treatment_type',
#  'ResearchSubject.Diagnosis.Treatment.treatment_outcome',
#  'ResearchSubject.Diagnosis.Treatment.days_to_treatment_start',
#  'ResearchSubject.Diagnosis.Treatment.days_to_treatment_end',
#  'ResearchSubject.Diagnosis.Treatment.therapeutic_agent',
#  'ResearchSubject.Diagnosis.Treatment.treatment_anatomic_site',
#  'ResearchSubject.Diagnosis.Treatment.treatment_effect',
#  'ResearchSubject.Diagnosis.Treatment.treatment_end_reason',
#  'ResearchSubject.Diagnosis.Treatment.number_of_cycles',
#  'ResearchSubject.Specimen.id',
#  'ResearchSubject.Specimen.identifier.system',
#  'ResearchSubject.Specimen.identifier.value',
#  'ResearchSubject.Specimen.associated_project',
#  'ResearchSubject.Specimen.days_to_collection',
#  'ResearchSubject.Specimen.primary_disease_type',
#  'ResearchSubject.Specimen.anatomical_site',
#  'ResearchSubject.Specimen.source_material_type',
#  'ResearchSubject.Specimen.specimen_type',
#  'ResearchSubject.Specimen.derived_from_specimen',
#  'ResearchSubject.Specimen.derived_from_subject']

# %% [markdown]
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
#
# There are a lot of columns in the CDA data, but Julia is most interested in diagnosis data, so she filters the list to only those:

# %%
columns().to_list(filters="diagnosis")
# Out:
# ['ResearchSubject.primary_diagnosis_condition',
#  'ResearchSubject.primary_diagnosis_site',
#  'ResearchSubject.Diagnosis.id',
#  'ResearchSubject.Diagnosis.identifier.system',
#  'ResearchSubject.Diagnosis.identifier.value',
#  'ResearchSubject.Diagnosis.primary_diagnosis',
#  'ResearchSubject.Diagnosis.age_at_diagnosis',
#  'ResearchSubject.Diagnosis.morphology',
#  'ResearchSubject.Diagnosis.stage',
#  'ResearchSubject.Diagnosis.grade',
#  'ResearchSubject.Diagnosis.method_of_diagnosis',
#  'ResearchSubject.Diagnosis.Treatment.id',
#  'ResearchSubject.Diagnosis.Treatment.identifier.system',
#  'ResearchSubject.Diagnosis.Treatment.identifier.value',
#  'ResearchSubject.Diagnosis.Treatment.treatment_type',
#  'ResearchSubject.Diagnosis.Treatment.treatment_outcome',
#  'ResearchSubject.Diagnosis.Treatment.days_to_treatment_start',
#  'ResearchSubject.Diagnosis.Treatment.days_to_treatment_end',
#  'ResearchSubject.Diagnosis.Treatment.therapeutic_agent',
#  'ResearchSubject.Diagnosis.Treatment.treatment_anatomic_site',
#  'ResearchSubject.Diagnosis.Treatment.treatment_effect',
#  'ResearchSubject.Diagnosis.Treatment.treatment_end_reason',
#  'ResearchSubject.Diagnosis.Treatment.number_of_cycles']

# %% [markdown]
# <div class="cdanote" style="background-color:#b3e5d5;color:black;padding:20px;">
#
# To search the CDA, a user also needs to know what search terms are available. Each column will contain a huge amount of data, so retreiving all of the rows would be overwhelming. Instead, the CDA has a `unique_terms()` function that will return all of the unique values that populate the requested column. Like `columns`, `unique_terms` defaults to giving us an overview of the results, and can be filtered.
#
# </div>
#
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# Since Julia is interested specificially in uterine cancers, she uses the `unique_terms` function to see what data is available for 'ResearchSubject.Diagnosis.Treatment.treatment_anatomic_site' and 'ResearchSubject.primary_diagnosis_site' to see if 'uterine' appears:

# %%
unique_terms("ResearchSubject.Diagnosis.Treatment.treatment_anatomic_site").to_list()
# Out:
# ['Brain',
#  'Cervix',
#  'Head - Face Or Neck, Nos',
#  'Lymph Node(s) Paraaortic',
#  'Other',
#  'Pelvis',
#  'Spine',
#  'Unknown']

# %%
unique_terms("ResearchSubject.primary_diagnosis_site").to_list()
# Out:
# ['Abdomen',
#  'Abdomen, Mediastinum',
#  'Abdomen, Pelvis',
#  'Adrenal Glands',
#  'Adrenal gland',
#  'Anus and anal canal',
#  'Base of tongue',
#  'Bile Duct',
#  'Bladder',
#  'Bones, joints and articular cartilage of limbs',
#  'Bones, joints and articular cartilage of other and unspecified sites',
#  'Brain',
#  'Breast',
#  'Bronchus and lung',
#  'Cervix',
#  'Cervix uteri',
#  'Chest',
#  'Chest-Abdomen-Pelvis, Leg, TSpine',
#  'Colon',
#  'Connective, subcutaneous and other soft tissues',
#  'Corpus uteri',
#  'Ear',
#  'Esophagus',
#  'Extremities',
#  'Eye and adnexa',
#  'Floor of mouth',
#  'Gallbladder',
#  'Gum',
#  'Head',
#  'Head and Neck',
#  'Head-Neck',
#  'Heart, mediastinum, and pleura',
#  'Hematopoietic and reticuloendothelial systems',
#  'Hypopharynx',
#  'Intraocular',
#  'Kidney',
#  'Larynx',
#  'Lip',
#  'Liver',
#  'Liver and intrahepatic bile ducts',
#  'Lung',
#  'Lung Phantom',
#  'Lymph nodes',
#  'Marrow, Blood',
#  'Meninges',
#  'Mesothelium',
#  'Nasal cavity and middle ear',
#  'Nasopharynx',
#  'Not Reported',
#  'Oropharynx',
#  'Other and ill-defined digestive organs',
#  'Other and ill-defined sites',
#  'Other and ill-defined sites in lip, oral cavity and pharynx',
#  'Other and ill-defined sites within respiratory system and intrathoracic organs',
#  'Other and unspecified female genital organs',
#  'Other and unspecified major salivary glands',
#  'Other and unspecified male genital organs',
#  'Other and unspecified parts of biliary tract',
#  'Other and unspecified parts of mouth',
#  'Other and unspecified parts of tongue',
#  'Other and unspecified urinary organs',
#  'Other endocrine glands and related structures',
#  'Ovary',
#  'Palate',
#  'Pancreas',
#  'Pancreas ',
#  'Pelvis, Prostate, Anus',
#  'Penis',
#  'Peripheral nerves and autonomic nervous system',
#  'Phantom',
#  'Prostate',
#  'Prostate gland',
#  'Rectosigmoid junction',
#  'Rectum',
#  'Renal pelvis',
#  'Retroperitoneum and peritoneum',
#  'Skin',
#  'Small intestine',
#  'Spinal cord, cranial nerves, and other parts of central nervous system',
#  'Stomach',
#  'Testicles',
#  'Testis',
#  'Thymus',
#  'Thyroid',
#  'Thyroid gland',
#  'Tonsil',
#  'Trachea',
#  'Unknown',
#  'Ureter',
#  'Uterus',
#  'Uterus, NOS',
#  'Vagina',
#  'Various',
#  'Various (11 locations)',
#  'Vulva']

# %% [markdown]
# <div class="cdanote" style="background-color:#b3e5d5;color:black;padding:20px;">
#
# CDA makes multiple datasets searchable from a common interface, but does not harmonize the data. This means that researchers should review all the terms in a column, and not just choose the first one that fits, as there may be other similar terms available as well.
#
# </div>

# %% [markdown]
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# Julia sees that "treatment_anatomic_site" does not have 'Uterine', but does have 'Cervix'. She also notes that both 'Uterus' and 'Uterus, NOS' are listed in the "primary_diagnosis_site" results. As she was initially looking for "uterine", Julia decides to expand her search a bit to account for variable naming schemes. So, she runs a fuzzy match filter on the "ResearchSubject.primary_diagnosis_site" for 'uter' as that should cover all variants:

# %%
unique_terms("ResearchSubject.primary_diagnosis_site").to_list(filters="uter")
# Out:
# ['Cervix uteri', 'Corpus uteri', 'Uterus', 'Uterus, NOS']

# %% [markdown]
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# Just to be sure, Julia also searches for any other instances of "cervix":

# %%
unique_terms("ResearchSubject.primary_diagnosis_site").to_list(filters="cerv")
# Out:
# ['Cervix', 'Cervix uteri']

# %% [markdown]
# ## Building a Query
#
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# With all her likely terms found, Julia begins to create a search that will get data for all of her terms. She does this by writing a series of `Q` statements that define what rows should be returned from each column. For the "treatment_anatomic_site", only one term is of interest, so she uses the `=` operator to get only exact matches:

# %%
Tsite = Q('ResearchSubject.Diagnosis.Treatment.treatment_anatomic_site = "Cervix"')

# %% [markdown]
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# However, for "primary_diagnosis_site", Julia has several terms she wants to search with. Luckily, `Q` also can run fuzzy searches. It can also search more than one term at a time, so Julia writes one big `Q` statement to grab everything that is either 'uter' or 'cerv':

# %%
Dsite = Q('ResearchSubject.primary_diagnosis_site = "%uter%" OR ResearchSubject.primary_diagnosis_site = "%cerv%"')

# %% [markdown]
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# Finally, Julia adds her two queries together into one large one:

# %%
ALLDATA = Tsite.OR(Dsite)

# %% [markdown]
# ## Looking at Summary Data
#
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# Now that Julia has a query, she can use it to look for data in any of the CDA endpoints. She starts by getting an overall summary of what data is available using `count`:

# %%
ALLDATA.count.run()
# Out:
# Getting results from database
# Total execution time: 4849 ms
# specimen_count : 40793
# treatment_count : 3049
# diagnosis_count : 3685
# researchsubject_count : 4869
# subject_count : 3742

# %% [markdown]
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# It seems there's a lot of data that might work for Julias study! Since she is interested in the beginings of cancer, she decides to start by looking at  the researchsubject information, since that is where most of the diagnosis information is. She again gets a summary using `count`:

# %%
ALLDATA.researchsubject.count.run()
# Out:
# Getting results from database
# Total execution time: 10077 ms
#     total : 4869
#    files : 324646
# <style type="text/css">
# #T_840c4_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_840c4_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_840c4_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_840c4_row0_col0" class="data row0 col0" >PDC</td>
#       <td id="T_840c4_row0_col1" class="data row0 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_840c4_row1_col0" class="data row1 col0" >GDC</td>
#       <td id="T_840c4_row1_col1" class="data row1 col1" >3591</td>
#     </tr>
#     <tr>
#       <td id="T_840c4_row2_col0" class="data row2 col0" >IDC</td>
#       <td id="T_840c4_row2_col1" class="data row2 col1" >1174</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9d42c_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_9d42c_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_9d42c_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_condition</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9d42c_row0_col0" class="data row0 col0" >Adenomas and Adenocarcinomas</td>
#       <td id="T_9d42c_row0_col1" class="data row0 col1" >1672</td>
#     </tr>
#     <tr>
#       <td id="T_9d42c_row1_col0" class="data row1 col0" >Uterine Corpus Endometrial Carcinoma</td>
#       <td id="T_9d42c_row1_col1" class="data row1 col1" >104</td>
#     </tr>
#     <tr>
#       <td id="T_9d42c_row2_col0" class="data row2 col0" >Myomatous Neoplasms</td>
#       <td id="T_9d42c_row2_col1" class="data row2 col1" >188</td>
#     </tr>
#     <tr>
#       <td id="T_9d42c_row3_col0" class="data row3 col0" >Squamous Cell Neoplasms</td>
#       <td id="T_9d42c_row3_col1" class="data row3 col1" >609</td>
#     </tr>
#     <tr>
#       <td id="T_9d42c_row4_col0" class="data row4 col0" >Cystic, Mucinous and Serous Neoplasms</td>
#       <td id="T_9d42c_row4_col1" class="data row4 col1" >487</td>
#     </tr>
#     <tr>
#       <td id="T_9d42c_row5_col0" class="data row5 col0" >Complex Mixed and Stromal Neoplasms</td>
#       <td id="T_9d42c_row5_col1" class="data row5 col1" >320</td>
#     </tr>
#     <tr>
#       <td id="T_9d42c_row6_col0" class="data row6 col0" >Not Reported</td>
#       <td id="T_9d42c_row6_col1" class="data row6 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_9d42c_row7_col0" class="data row7 col0" >None</td>
#       <td id="T_9d42c_row7_col1" class="data row7 col1" >1175</td>
#     </tr>
#     <tr>
#       <td id="T_9d42c_row8_col0" class="data row8 col0" >Complex Epithelial Neoplasms</td>
#       <td id="T_9d42c_row8_col1" class="data row8 col1" >27</td>
#     </tr>
#     <tr>
#       <td id="T_9d42c_row9_col0" class="data row9 col0" >Epithelial Neoplasms, NOS</td>
#       <td id="T_9d42c_row9_col1" class="data row9 col1" >230</td>
#     </tr>
#     <tr>
#       <td id="T_9d42c_row10_col0" class="data row10 col0" >Soft Tissue Tumors and Sarcomas, NOS</td>
#       <td id="T_9d42c_row10_col1" class="data row10 col1" >14</td>
#     </tr>
#     <tr>
#       <td id="T_9d42c_row11_col0" class="data row11 col0" >Trophoblastic neoplasms</td>
#       <td id="T_9d42c_row11_col1" class="data row11 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_9d42c_row12_col0" class="data row12 col0" >Neoplasms, NOS</td>
#       <td id="T_9d42c_row12_col1" class="data row12 col1" >12</td>
#     </tr>
#     <tr>
#       <td id="T_9d42c_row13_col0" class="data row13 col0" >Mesonephromas</td>
#       <td id="T_9d42c_row13_col1" class="data row13 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_9d42c_row14_col0" class="data row14 col0" >Neuroepitheliomatous Neoplasms</td>
#       <td id="T_9d42c_row14_col1" class="data row14 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_02069_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_02069_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_02069_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >primary_diagnosis_site</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_02069_row0_col0" class="data row0 col0" >Cervix uteri</td>
#       <td id="T_02069_row0_col1" class="data row0 col1" >915</td>
#     </tr>
#     <tr>
#       <td id="T_02069_row1_col0" class="data row1 col0" >Uterus, NOS</td>
#       <td id="T_02069_row1_col1" class="data row1 col1" >2000</td>
#     </tr>
#     <tr>
#       <td id="T_02069_row2_col0" class="data row2 col0" >Corpus uteri</td>
#       <td id="T_02069_row2_col1" class="data row2 col1" >780</td>
#     </tr>
#     <tr>
#       <td id="T_02069_row3_col0" class="data row3 col0" >Uterus</td>
#       <td id="T_02069_row3_col1" class="data row3 col1" >867</td>
#     </tr>
#     <tr>
#       <td id="T_02069_row4_col0" class="data row4 col0" >Cervix</td>
#       <td id="T_02069_row4_col1" class="data row4 col1" >307</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Refining Queries
#
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# Browsing the primary_diagnosis_condition data, Julia notices that there are a large number of research subjects that are Adenomas and Adenocarcinomas. Since Julia wants to look for common phenotypes in early cancers, she decides it might be easier to exclude the endocrine related data, as they might have different mechanisms. So she adds a new filter to her query:

# %%
Noadeno = Q('ResearchSubject.primary_diagnosis_condition != "Adenomas and Adenocarcinomas"')

NoAdenoData = ALLDATA.AND(Noadeno)

NoAdenoData.researchsubject.count.run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_92/1888651251.py in <cell line: 3>()
#       1 Noadeno = Q('ResearchSubject.primary_diagnosis_condition != "Adenomas and Adenocarcinomas"')
#       2
# ----> 3 NoAdenoData = ALLDATA.AND(Noadeno)
#       4
#       5 NoAdenoData.researchsubject.count.run()
#
# NameError: name 'ALLDATA' is not defined

# %% [markdown]
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# She then previews the actual metadata for researchsubject, subject, and file, to make sure that they have all the information she will need for her work. Since she's mostly interested in looking at the kinds of data available from each endpoint:

# %%
NoAdenoData.researchsubject.run().to_dataframe() # view the dataframe
# Out:
# Getting results from database
# Total execution time: 4063 ms
#                                       id  \
# 0   0609d8ac-fc18-4e07-b5fb-12b372151dcf
# 1   1d2937e8-6104-4330-b7dc-7bcd79dac927
# 2   2639fc46-2bf7-4050-b5dd-c4d8beb89d2e
# 3   30a4fa5d-98f4-4592-868f-2beb443eb82d
# 4   30ffb337-c844-493f-97d6-7aea157d1b5e
# ..                                   ...
# 95                TCGA-N8-A4PN__tcga_ucs
# 96                TCGA-ND-A4WA__tcga_ucs
# 97  a6a07bc7-ab1b-429d-81ed-d7a890c88e51
# 98  a7f3f44f-5d75-4572-80e6-279f186e44a3
# 99  cca23650-1b06-4977-91e8-f35e73e70c48
#
#                                            identifier  \
# 0   [{'system': 'GDC', 'value': '0609d8ac-fc18-4e0...
# 1   [{'system': 'GDC', 'value': '1d2937e8-6104-433...
# 2   [{'system': 'GDC', 'value': '2639fc46-2bf7-405...
# 3   [{'system': 'GDC', 'value': '30a4fa5d-98f4-459...
# 4   [{'system': 'GDC', 'value': '30ffb337-c844-493...
# ..                                                ...
# 95  [{'system': 'IDC', 'value': 'TCGA-N8-A4PN__tcg...
# 96  [{'system': 'IDC', 'value': 'TCGA-ND-A4WA__tcg...
# 97  [{'system': 'GDC', 'value': 'a6a07bc7-ab1b-429...
# 98  [{'system': 'GDC', 'value': 'a7f3f44f-5d75-457...
# 99  [{'system': 'GDC', 'value': 'cca23650-1b06-497...
#
#    member_of_research_project            primary_diagnosis_condition  \
# 0                  GENIE-DFCI   Soft Tissue Tumors and Sarcomas, NOS
# 1                    TCGA-UCS    Complex Mixed and Stromal Neoplasms
# 2                   GENIE-MSK                    Myomatous Neoplasms
# 3                       FM-AD  Cystic, Mucinous and Serous Neoplasms
# 4               CGCI-HTMCP-CC                Squamous Cell Neoplasms
# ..                        ...                                    ...
# 95                   tcga_ucs                                   None
# 96                   tcga_ucs                                   None
# 97                  TCGA-CESC  Cystic, Mucinous and Serous Neoplasms
# 98                  GENIE-MSK              Epithelial Neoplasms, NOS
# 99                  TCGA-CESC                Squamous Cell Neoplasms
#
#    primary_diagnosis_site           subject_id
# 0             Uterus, NOS    GENIE-DFCI-011667
# 1             Uterus, NOS         TCGA-N5-A4RN
# 2             Uterus, NOS  GENIE-MSK-P-0003476
# 3             Uterus, NOS              AD13447
# 4            Cervix uteri    HTMCP-03-06-02240
# ..                    ...                  ...
# 95                 Uterus         TCGA-N8-A4PN
# 96                 Uterus         TCGA-ND-A4WA
# 97           Cervix uteri         TCGA-VS-A9V1
# 98            Uterus, NOS  GENIE-MSK-P-0018781
# 99           Cervix uteri         TCGA-VS-A9UC
#
# [100 rows x 6 columns]

# %% [markdown]
# ---
#
# <div class="cdadefine" style="background-color:#add9e5;color:black;padding:20px;">
#
# <h3>ResearchSubject Field Definitions</h3>
#
# <i>A research subject is the entity of interest in a specific research study or project, typically a human being or an animal, but can also be a device, group of humans or animals, or a tissue sample. Human research subjects are usually not traceable to a particular person to protect the subjects privacy. This entity plays the role of the case_id in existing data. An individual who participates in 3 studies will have 3 researchsubject IDs</i>
#
# <ul>
# <li><b>id:</b> The 'logical' identifier of the entity in the system of record, e.g. a UUID. This 'id' is unique within a given system. The identified entity may have a different 'id' in a different system. For CDA, this is case_id.</li>
# <li><b>identifier:</b> A 'business' identifier for the entity, typically as provided by an external system or authority, that persists across implementing systems (i.e. a 'logical' identifier). Uses a specialized, complex 'Identifier' data type to capture information about the source of the business identifier - or a URI expressed as a string to an existing entity.</li>
# <li><b>identifier.system:</b> The system or namespace that defines the identifier.</li>
# <li><b>identifier.value:</b> The value of the identifier, as defined by the system.</li>
# <li><b>member_of_research_project:</b> A reference to the Study(s) of which this ResearchSubject is a member.</li>
# <li><b>primary_diagnosis_condition:</b> The text term used to describe the type of malignant disease, as categorized by the World Health Organization's (WHO) <a href="https://www.who.int/standards/classifications/other-classifications/international-classification-of-diseases-for-oncology">International Classification of Diseases for Oncology</a> (ICD-O). This attribute represents the disease that qualified the subject for inclusion on the ResearchProject.</li>
# <li><b>primary_diagnosis_site:</b> The text term used to describe the primary site of disease, as categorized by the World Health Organization's (WHO) <a href="https://www.who.int/standards/classifications/other-classifications/international-classification-of-diseases-for-oncology">International Classification of Diseases for Oncology</a> (ICD-O). This categorization groups cases into general categories. This attribute represents the primary site of disease that qualified the subject for inclusion on the ResearchProject.</li>
# <li><b>subject_id:</b> The 'logical' identifier of the entity in the system of record, e.g. a UUID. This 'id' is unique within a given system. The identified entity may have a different 'id' in a different system. Can be joined to the `id` field from subject results</li>
# </ul>
#
# </div>
#
# ---

# %%
NoAdenoData.subject.run().to_dataframe() # view the dataframe
# Out:
# Getting results from database
# Total execution time: 3838 ms
#                      id                                         identifier  \
# 0               AD15141            [{'system': 'GDC', 'value': 'AD15141'}]
# 1                 AD290              [{'system': 'GDC', 'value': 'AD290'}]
# 2                AD4252             [{'system': 'GDC', 'value': 'AD4252'}]
# 3                AD9808             [{'system': 'GDC', 'value': 'AD9808'}]
# 4             C3L-02382          [{'system': 'IDC', 'value': 'C3L-02382'}]
# ..                  ...                                                ...
# 95  GENIE-MSK-P-0001439  [{'system': 'GDC', 'value': 'GENIE-MSK-P-00014...
# 96  GENIE-MSK-P-0001606  [{'system': 'GDC', 'value': 'GENIE-MSK-P-00016...
# 97  GENIE-MSK-P-0001989  [{'system': 'GDC', 'value': 'GENIE-MSK-P-00019...
# 98  GENIE-MSK-P-0013913  [{'system': 'GDC', 'value': 'GENIE-MSK-P-00139...
# 99  GENIE-MSK-P-0015139  [{'system': 'GDC', 'value': 'GENIE-MSK-P-00151...
#
#          species     sex          race               ethnicity  days_to_birth  \
# 0   homo sapiens  female  not reported            not reported            NaN
# 1   homo sapiens  female  not reported            not reported            NaN
# 2   homo sapiens  female  not reported            not reported            NaN
# 3   homo sapiens  female  not reported            not reported            NaN
# 4   Homo sapiens    None          None                    None            NaN
# ..           ...     ...           ...                     ...            ...
# 95  homo sapiens  female         white  not hispanic or latino       -28854.0
# 96  homo sapiens  female         white  not hispanic or latino       -21549.0
# 97  homo sapiens  female         white  not hispanic or latino       -14610.0
# 98  homo sapiens  female         white  not hispanic or latino       -20454.0
# 99  homo sapiens  female         white  not hispanic or latino       -26298.0
#
#    subject_associated_project  vital_status  days_to_death cause_of_death
# 0                     [FM-AD]  Not Reported            NaN           None
# 1                     [FM-AD]  Not Reported            NaN           None
# 2                     [FM-AD]  Not Reported            NaN           None
# 3                     [FM-AD]  Not Reported            NaN           None
# 4                [cptac_ucec]          None            NaN           None
# ..                        ...           ...            ...            ...
# 95                [GENIE-MSK]  Not Reported            NaN           None
# 96                [GENIE-MSK]  Not Reported            NaN           None
# 97                [GENIE-MSK]  Not Reported            NaN           None
# 98                [GENIE-MSK]  Not Reported            NaN           None
# 99                [GENIE-MSK]  Not Reported            NaN           None
#
# [100 rows x 11 columns]

# %% [markdown]
# ---
#
# <div class="cdadefine" style="background-color:#add9e5;color:black;padding:20px;">
#
# <h3>Subject Field Definitions</h3>
#
# <i>A patient entity captures the study-independent metadata for research subjects. Human research subjects are usually not traceable to a particular person to protect the subjects privacy.</i>
#
#
# <ul>
# <li><b>id:</b> The 'logical' identifier of the entity in the system of record, e.g. a UUID. This 'id' is unique within a given system. The identified entity may have a different 'id' in a different system.",STRING</li>
# <li><b>identifier:</b> A 'business' identifier for the entity, typically as provided by an external system or authority, that persists across implementing systems (i.e. a 'logical' identifier). Uses a specialized, complex 'Identifier' data type to capture information about the source of the business identifier - or a URI expressed as a string to an existing entity.</li>
# <li><b>identifier.system:</b> The system or namespace that defines the identifier.</li>
# <li><b>identifier.value:</b> The value of the identifier, as defined by the system.</li>
# <li><b>species:</b> The taxonomic group (e.g. species) of the patient. For MVP, since taxonomy vocabulary is consistent between GDC and PDC, using text. Ultimately, this will be a term returned by the vocabulary service.</li>
# <li><b>sex:</b> The biologic character or quality that distinguishes male and female from one another as expressed by analysis of the person's gonadal, morphologic (internal and external), chromosomal, and hormonal characteristics.</li>
# <li><b>race:</b> An arbitrary classification of a taxonomic group that is a division of a species. It usually arises as a consequence of geographical isolation within a species and is characterized by shared heredity, physical attributes and behavior, and in the case of humans, by common history, nationality, or geographic distribution. The provided values are based on the categories defined by the U.S. Office of Management and Business and used by the U.S. Census Bureau.</li>
# <li><b>ethnicity:</b> An individual's self-described social and cultural grouping, specifically whether an individual describes themselves as Hispanic or Latino. The provided values are based on the categories defined by the U.S. Office of Management and Business and used by the U.S. Census Bureau.</li>
# <li><b>days_to_birth:</b> Number of days between the date used for index and the date from a person's date of birth represented as a calculated negative number of days.</li>
# <li><b>subject_associated_project:</b> The list of Projects associated with the Subject.</li>
# <li><b>vital_status:</b> Coded value indicating the state or condition of being living or deceased; also includes the case where the vital status is unknown.</li>
# <li><b>days_to_death:</b> Number of days between the date used for index and the date from a person's date of death represented as a calculated number of days.</li>
# <li><b>cause_of_death:</b> Coded value indicating the circumstance or condition that results in the death of the subject.</li>
# </ul>
#
# </div>
#
# ---

# %%
NoAdenoData.file.run().to_dataframe() # view the dataframe
# Out:
# Getting results from database
# Total execution time: 21458 ms
#                                       id  \
# 0   002ff7dd-d55c-4f60-8d9a-c814443ed665
# 1   00305181-fec7-41c6-a143-f3bf4636bd5f
# 2   005ff5ca-0975-4b0b-b413-4a906701e923
# 3   007c3c99-c50f-4e45-907a-7ab78f47ff0d
# 4   00a7b64e-ffd2-11e8-abd7-005056921935
# ..                                   ...
# 95  6a95c4ba-ffb4-11e8-95a3-005056921935
# 96  6afce870-f915-11e8-90c1-005056921935
# 97  6b78fe54-ffcf-11e8-9f26-005056921935
# 98  6bcbea24-ffcf-11e8-9f26-005056921935
# 99  6be95f00-ffcf-11e8-9f26-005056921935
#
#                                            identifier  \
# 0   [{'system': 'GDC', 'value': '002ff7dd-d55c-4f6...
# 1   [{'system': 'GDC', 'value': '00305181-fec7-41c...
# 2   [{'system': 'GDC', 'value': '005ff5ca-0975-4b0...
# 3   [{'system': 'GDC', 'value': '007c3c99-c50f-4e4...
# 4   [{'system': 'PDC', 'value': '00a7b64e-ffd2-11e...
# ..                                                ...
# 95  [{'system': 'PDC', 'value': '6a95c4ba-ffb4-11e...
# 96  [{'system': 'PDC', 'value': '6afce870-f915-11e...
# 97  [{'system': 'PDC', 'value': '6b78fe54-ffcf-11e...
# 98  [{'system': 'PDC', 'value': '6bcbea24-ffcf-11e...
# 99  [{'system': 'PDC', 'value': '6be95f00-ffcf-11e...
#
#                                                 label  \
# 0   9e4a57ec-ca07-4843-b77f-eb5504a817c4.rna_seq.c...
# 1   39550f2d-268b-47a8-996c-7638f07de1dd.wxs.muse....
# 2   f059db9c-510f-4dc0-bf36-6038149bf06a.wxs.somat...
# 3   TCGA_UCS.7ea16309-04b4-41ff-93aa-dc3605be9fc7....
# 4       15CPTAC_UCEC_P_PNNL_20180503_B4S3_f08.mzid.gz
# ..                                                ...
# 95      07CPTAC_UCEC_W_PNNL_20170922_B2S3_f18.mzML.gz
# 96          10CPTAC_UCEC_P_PNNL_20180222_B3S2_f04.raw
# 97          03CPTAC_UCEC_P_PNNL_20170922_B1S3_f05.psm
# 98          03CPTAC_UCEC_P_PNNL_20170922_B1S3_f08.psm
# 99          03CPTAC_UCEC_P_PNNL_20170922_B1S3_f09.psm
#
#                   data_category                    data_type      file_format  \
# 0              Sequencing Reads                Aligned Reads              BAM
# 1   Simple Nucleotide Variation  Raw Simple Somatic Mutation              VCF
# 2   Simple Nucleotide Variation  Raw Simple Somatic Mutation              VCF
# 3   Simple Nucleotide Variation   Annotated Somatic Mutation              VCF
# 4      Peptide Spectral Matches                Open Standard        mzIdentML
# ..                          ...                          ...              ...
# 95       Processed Mass Spectra                Open Standard             mzML
# 96             Raw Mass Spectra                  Proprietary  vendor-specific
# 97     Peptide Spectral Matches                         Text              tsv
# 98     Peptide Spectral Matches                         Text              tsv
# 99     Peptide Spectral Matches                         Text              tsv
#
#    associated_project                                            drs_uri  \
# 0           TCGA-CESC  drs://dg.4DFC:002ff7dd-d55c-4f60-8d9a-c814443e...
# 1           TCGA-UCEC  drs://dg.4DFC:00305181-fec7-41c6-a143-f3bf4636...
# 2           TCGA-CESC  drs://dg.4DFC:005ff5ca-0975-4b0b-b413-4a906701...
# 3            TCGA-UCS  drs://dg.4DFC:007c3c99-c50f-4e45-907a-7ab78f47...
# 4    CPTAC3-Discovery  drs://dg.4DFC:00a7b64e-ffd2-11e8-abd7-00505692...
# ..                ...                                                ...
# 95   CPTAC3-Discovery  drs://dg.4DFC:6a95c4ba-ffb4-11e8-95a3-00505692...
# 96   CPTAC3-Discovery  drs://dg.4DFC:6afce870-f915-11e8-90c1-00505692...
# 97   CPTAC3-Discovery  drs://dg.4DFC:6b78fe54-ffcf-11e8-9f26-00505692...
# 98   CPTAC3-Discovery  drs://dg.4DFC:6bcbea24-ffcf-11e8-9f26-00505692...
# 99   CPTAC3-Discovery  drs://dg.4DFC:6be95f00-ffcf-11e8-9f26-00505692...
#
#     byte_size                          checksum data_modality  \
# 0    96671613  6a4989df92ba58fe6558e7f6d0d5eb0f       Genomic
# 1       25035  42b1a48e34690de6cd6851ca753cff9d       Genomic
# 2      268168  4174aa64898dfbdf2a73634c73b77d01       Genomic
# 3      229002  8d2de6c206adef0e1236a1008d9234f9       Genomic
# 4     5832060  194e198498ab1c3ff18984bff2ef28a9     Proteomic
# ..        ...                               ...           ...
# 95  231084046  4eccdcd78267609a2e6e0cdd6d1f075f     Proteomic
# 96  806180410  625413aa5fece36dc7fa5375f92580ec     Proteomic
# 97    2957979  71d54336cc42e41228484d9399d22f59     Proteomic
# 98    2496941  bb2eb73c4d58f988538ca5b6b8453cfb     Proteomic
# 99    2446411  002357b9fcbb60216779c3ef40bb225b     Proteomic
#
#    imaging_modality dbgap_accession_number imaging_series  \
# 0              None                   None           None
# 1              None                   None           None
# 2              None                   None           None
# 3              None                   None           None
# 4              None                   None           None
# ..              ...                    ...            ...
# 95             None                   None           None
# 96             None                   None           None
# 97             None                   None           None
# 98             None                   None           None
# 99             None                   None           None
#
#              researchsubject_specimen_id  \
# 0   a36de57d-2315-4bc3-93bf-69ec4f51063b
# 1   987af661-a8b7-47b0-800f-a0b6a3ef0096
# 2   8a53198f-ee29-4cca-8cb2-9944790bcc53
# 3   e8dc4a59-fdfb-40d0-afc9-f7f21eb0f339
# 4   61c4d96e-1259-11e9-afb9-0a9c39d33490
# ..                                   ...
# 95  c8a6ef50-1259-11e9-afb9-0a9c39d33490
# 96  d799fbea-1271-11e9-afb9-0a9c39d33490
# 97  39743eb5-1259-11e9-afb9-0a9c39d33490
# 98  bb56d00f-1258-11e9-afb9-0a9c39d33490
# 99  74ef895e-1271-11e9-afb9-0a9c39d33490
#
#                       researchsubject_id    subject_id
# 0   0bd52d75-5113-4ef1-bc75-509f59eaef2b  TCGA-JW-A5VG
# 1   e31db89c-15ac-45a4-9788-afb339b0f3bc  TCGA-AX-A3G6
# 2   e15d92a1-6925-4b58-a494-d6f665f67b83  TCGA-LP-A4AU
# 3   a1206473-cf9d-4bca-97c9-67f35817b806  TCGA-N9-A4Q1
# 4   7ef278e9-118a-11e9-afb9-0a9c39d33490     C3L-01925
# ..                                   ...           ...
# 95  bf1f593d-118a-11e9-afb9-0a9c39d33490     C3N-01217
# 96  c289029e-118a-11e9-afb9-0a9c39d33490     C3N-01267
# 97  6b043589-118a-11e9-afb9-0a9c39d33490     C3L-01256
# 98  f91c655f-1189-11e9-afb9-0a9c39d33490     C3L-00358
# 99  f91c655f-1189-11e9-afb9-0a9c39d33490     C3L-00358
#
# [100 rows x 17 columns]

# %% [markdown]
# ---
#
# <div class="cdadefine" style="background-color:#add9e5;color:black;padding:20px;">
#
# <h3>File Field Definitions</h3>
#
# <i>A file is an information-bearing electronic object that contains a physical embodiment of some information using a particular character encoding.</i>
#
#
# <ul>
#   <li><b>id:</b> The 'logical' identifier of the entity in the system of record, e.g. a UUID. This 'id' is unique within a given system. The identified entity may have a different 'id' in a different system.</li>
# <li><b>identifier:</b> A 'business' identifier for the entity, typically as provided by an external system or authority, that persists across implementing systems (i.e. a 'logical' identifier). Uses a specialized, complex 'Identifier' data type to capture information about the source of the business identifier - or a URI expressed as a string to an existing entity.</li>
# <li><b>identifier.system:</b> The system or namespace that defines the identifier.</li>
# <li><b>identifier.value:</b> The value of the identifier, as defined by the system.</li>
#   <li><b>label:</b> Short name or abbreviation for dataset. Maps to rdfs:label.</li>
#   <li><b>data_catagory:</b> Broad categorization of the contents of the data file.</li>
#   <li><b>data_type:</b> Specific content type of the data file.</li>
#   <li><b>file_format:</b> Format of the data files.</li>
#   <li><b>associated_project:</b> A reference to the Project(s) of which this ResearchSubject is a member. The associated_project may be embedded using the ref definition or may be a reference to the id for the Project - or a URI expressed as a string to an existing entity.</li>
#   <li><b>drs_uri:</b> A string of characters used to identify a resource on the Data Repo Service(DRS). Can be used to retreive this specific file from a server.</li>
#   <li><b>byte_size:</b> Size of the file in bytes. Maps to dcat:byteSize.</li>
#   <li><b>checksum:</b> The md5 value for the file. A digit representing the sum of the correct digits in a piece of stored or transmitted digital data, against which later comparisons can be made to detect errors in the data.</li>
#   <li><b>data_modality:</b> Data modality describes the biological nature of the information gathered as the result of an Activity, independent of the technology or methods used to produce the information. Always one of "Genomic", "Proteomic", or "Imaging".</li>
#   <li><b>imaging_modality:</b> An imaging modality describes the imaging equipment and/or method used to acquire certain structural or functional information about the body. These include but are not limited to computed tomography (CT) and magnetic resonance imaging (MRI). Taken from the DICOM standard.</li>
#   <li><b>dbgap_accession_number:</b> The dbgap accession number for the project.</li>
# </ul>
#
# </div>
#
# ---

# %% [markdown]
# ## Working with Results (pagination)
#
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# Finally, Julia wants to save these results to use for the future. Since the preview dataframes only show the first 100 results of each search, she uses the `paginator` function to get all the data from the subject and researchsubject endpoints into their own dataframes:

# %%
researchsubs = NoAdenoData.researchsubject.run()
rsdf = pd.DataFrame()
for i in researchsubs.paginator(to_df=True):
    rsdf = pd.concat([rsdf, i])
# Out:
# Getting results from database
# Total execution time: 3540 ms

# %%
subs = NoAdenoData.subject.run()
subsdf = pd.DataFrame()
for i in subs.paginator(to_df=True):
    subsdf = pd.concat([subsdf, i])
# Out:
# Getting results from database
# Total execution time: 3538 ms

# %%
rsdf # view the researchsubject dataframe
# Out:
#                                       id  \
# 0   0609d8ac-fc18-4e07-b5fb-12b372151dcf
# 1   1d2937e8-6104-4330-b7dc-7bcd79dac927
# 2   2639fc46-2bf7-4050-b5dd-c4d8beb89d2e
# 3   30a4fa5d-98f4-4592-868f-2beb443eb82d
# 4   30ffb337-c844-493f-97d6-7aea157d1b5e
# ..                                   ...
# 92  da85e3db-253d-4331-bf09-b4228d6c301a
# 93  db7036b1-1427-49fc-9381-2df96ee45faf
# 94  ed12e8d3-570b-4f63-b236-c807c523c7d0
# 95  ede93186-676f-4ebc-a750-60607929b0d1
# 96  f5afc8b8-5f01-4137-b333-6f3712bf4682
#
#                                            identifier  \
# 0   [{'system': 'GDC', 'value': '0609d8ac-fc18-4e0...
# 1   [{'system': 'GDC', 'value': '1d2937e8-6104-433...
# 2   [{'system': 'GDC', 'value': '2639fc46-2bf7-405...
# 3   [{'system': 'GDC', 'value': '30a4fa5d-98f4-459...
# 4   [{'system': 'GDC', 'value': '30ffb337-c844-493...
# ..                                                ...
# 92  [{'system': 'GDC', 'value': 'da85e3db-253d-433...
# 93  [{'system': 'GDC', 'value': 'db7036b1-1427-49f...
# 94  [{'system': 'GDC', 'value': 'ed12e8d3-570b-4f6...
# 95  [{'system': 'GDC', 'value': 'ede93186-676f-4eb...
# 96  [{'system': 'GDC', 'value': 'f5afc8b8-5f01-413...
#
#    member_of_research_project            primary_diagnosis_condition  \
# 0                  GENIE-DFCI   Soft Tissue Tumors and Sarcomas, NOS
# 1                    TCGA-UCS    Complex Mixed and Stromal Neoplasms
# 2                   GENIE-MSK                    Myomatous Neoplasms
# 3                       FM-AD  Cystic, Mucinous and Serous Neoplasms
# 4               CGCI-HTMCP-CC                Squamous Cell Neoplasms
# ..                        ...                                    ...
# 92              CGCI-HTMCP-CC                Squamous Cell Neoplasms
# 93                 GENIE-DFCI                Trophoblastic neoplasms
# 94                 GENIE-DFCI                Trophoblastic neoplasms
# 95                  GENIE-MSK  Cystic, Mucinous and Serous Neoplasms
# 96                  GENIE-UHN                    Myomatous Neoplasms
#
#    primary_diagnosis_site           subject_id
# 0             Uterus, NOS    GENIE-DFCI-011667
# 1             Uterus, NOS         TCGA-N5-A4RN
# 2             Uterus, NOS  GENIE-MSK-P-0003476
# 3             Uterus, NOS              AD13447
# 4            Cervix uteri    HTMCP-03-06-02240
# ..                    ...                  ...
# 92           Cervix uteri    HTMCP-03-06-02210
# 93            Uterus, NOS    GENIE-DFCI-007248
# 94            Uterus, NOS    GENIE-DFCI-000252
# 95            Uterus, NOS  GENIE-MSK-P-0015430
# 96            Uterus, NOS     GENIE-UHN-365307
#
# [3197 rows x 6 columns]

# %%
subsdf # view the subject dataframe
# Out:
#               id                                         identifier  \
# 0        AD15141            [{'system': 'GDC', 'value': 'AD15141'}]
# 1          AD290              [{'system': 'GDC', 'value': 'AD290'}]
# 2         AD4252             [{'system': 'GDC', 'value': 'AD4252'}]
# 3         AD9808             [{'system': 'GDC', 'value': 'AD9808'}]
# 4      C3L-02382          [{'system': 'IDC', 'value': 'C3L-02382'}]
# ..           ...                                                ...
# 4   TCGA-D1-A17K  [{'system': 'GDC', 'value': 'TCGA-D1-A17K'}, {...
# 5   TCGA-EK-A2R8  [{'system': 'GDC', 'value': 'TCGA-EK-A2R8'}, {...
# 6   TCGA-N6-A4VC  [{'system': 'GDC', 'value': 'TCGA-N6-A4VC'}, {...
# 7   TCGA-N7-A4Y5  [{'system': 'GDC', 'value': 'TCGA-N7-A4Y5'}, {...
# 8   TCGA-VS-A8EJ  [{'system': 'GDC', 'value': 'TCGA-VS-A8EJ'}, {...
#
#          species     sex          race               ethnicity  days_to_birth  \
# 0   homo sapiens  female  not reported            not reported            NaN
# 1   homo sapiens  female  not reported            not reported            NaN
# 2   homo sapiens  female  not reported            not reported            NaN
# 3   homo sapiens  female  not reported            not reported            NaN
# 4   Homo sapiens    None          None                    None            NaN
# ..           ...     ...           ...                     ...            ...
# 4   homo sapiens  female         white  not hispanic or latino       -27283.0
# 5   homo sapiens  female         white  not hispanic or latino       -17692.0
# 6   homo sapiens  female         white  not hispanic or latino       -30643.0
# 7   homo sapiens  female         white            not reported       -32058.0
# 8   homo sapiens  female         white            not reported       -22000.0
#
#    subject_associated_project  vital_status  days_to_death cause_of_death
# 0                     [FM-AD]  Not Reported            NaN           None
# 1                     [FM-AD]  Not Reported            NaN           None
# 2                     [FM-AD]  Not Reported            NaN           None
# 3                     [FM-AD]  Not Reported            NaN           None
# 4                [cptac_ucec]          None            NaN           None
# ..                        ...           ...            ...            ...
# 4      [TCGA-UCEC, tcga_ucec]         Alive            NaN           None
# 5      [TCGA-CESC, tcga_cesc]         Alive            NaN           None
# 6        [TCGA-UCS, tcga_ucs]          Dead          597.0           None
# 7        [TCGA-UCS, tcga_ucs]          Dead            8.0           None
# 8      [TCGA-CESC, tcga_cesc]          Dead          607.0           None
#
# [2609 rows x 11 columns]

# %% [markdown]
# ## Merging Results across Endpoints
#
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# Then Julia uses the `id` fields in each result to merge them together into one big dataset:

# %%
allmetadata = pd.merge(rsdf,
                subsdf,
                left_on="subject_id",
                right_on='id')

allmetadata
# Out:
#                                       id_x  \
# 0     0609d8ac-fc18-4e07-b5fb-12b372151dcf
# 1     1d2937e8-6104-4330-b7dc-7bcd79dac927
# 2                   TCGA-N5-A4RN__tcga_ucs
# 3     2639fc46-2bf7-4050-b5dd-c4d8beb89d2e
# 4     30a4fa5d-98f4-4592-868f-2beb443eb82d
# ...                                    ...
# 3192  da85e3db-253d-4331-bf09-b4228d6c301a
# 3193  db7036b1-1427-49fc-9381-2df96ee45faf
# 3194  ed12e8d3-570b-4f63-b236-c807c523c7d0
# 3195  ede93186-676f-4ebc-a750-60607929b0d1
# 3196  f5afc8b8-5f01-4137-b333-6f3712bf4682
#
#                                            identifier_x  \
# 0     [{'system': 'GDC', 'value': '0609d8ac-fc18-4e0...
# 1     [{'system': 'GDC', 'value': '1d2937e8-6104-433...
# 2     [{'system': 'IDC', 'value': 'TCGA-N5-A4RN__tcg...
# 3     [{'system': 'GDC', 'value': '2639fc46-2bf7-405...
# 4     [{'system': 'GDC', 'value': '30a4fa5d-98f4-459...
# ...                                                 ...
# 3192  [{'system': 'GDC', 'value': 'da85e3db-253d-433...
# 3193  [{'system': 'GDC', 'value': 'db7036b1-1427-49f...
# 3194  [{'system': 'GDC', 'value': 'ed12e8d3-570b-4f6...
# 3195  [{'system': 'GDC', 'value': 'ede93186-676f-4eb...
# 3196  [{'system': 'GDC', 'value': 'f5afc8b8-5f01-413...
#
#      member_of_research_project            primary_diagnosis_condition  \
# 0                    GENIE-DFCI   Soft Tissue Tumors and Sarcomas, NOS
# 1                      TCGA-UCS    Complex Mixed and Stromal Neoplasms
# 2                      tcga_ucs                                   None
# 3                     GENIE-MSK                    Myomatous Neoplasms
# 4                         FM-AD  Cystic, Mucinous and Serous Neoplasms
# ...                         ...                                    ...
# 3192              CGCI-HTMCP-CC                Squamous Cell Neoplasms
# 3193                 GENIE-DFCI                Trophoblastic neoplasms
# 3194                 GENIE-DFCI                Trophoblastic neoplasms
# 3195                  GENIE-MSK  Cystic, Mucinous and Serous Neoplasms
# 3196                  GENIE-UHN                    Myomatous Neoplasms
#
#      primary_diagnosis_site           subject_id                 id_y  \
# 0               Uterus, NOS    GENIE-DFCI-011667    GENIE-DFCI-011667
# 1               Uterus, NOS         TCGA-N5-A4RN         TCGA-N5-A4RN
# 2                    Uterus         TCGA-N5-A4RN         TCGA-N5-A4RN
# 3               Uterus, NOS  GENIE-MSK-P-0003476  GENIE-MSK-P-0003476
# 4               Uterus, NOS              AD13447              AD13447
# ...                     ...                  ...                  ...
# 3192           Cervix uteri    HTMCP-03-06-02210    HTMCP-03-06-02210
# 3193            Uterus, NOS    GENIE-DFCI-007248    GENIE-DFCI-007248
# 3194            Uterus, NOS    GENIE-DFCI-000252    GENIE-DFCI-000252
# 3195            Uterus, NOS  GENIE-MSK-P-0015430  GENIE-MSK-P-0015430
# 3196            Uterus, NOS     GENIE-UHN-365307     GENIE-UHN-365307
#
#                                            identifier_y       species     sex  \
# 0     [{'system': 'GDC', 'value': 'GENIE-DFCI-011667'}]  homo sapiens  female
# 1     [{'system': 'GDC', 'value': 'TCGA-N5-A4RN'}, {...  homo sapiens  female
# 2     [{'system': 'GDC', 'value': 'TCGA-N5-A4RN'}, {...  homo sapiens  female
# 3     [{'system': 'GDC', 'value': 'GENIE-MSK-P-00034...  homo sapiens  female
# 4               [{'system': 'GDC', 'value': 'AD13447'}]  homo sapiens  female
# ...                                                 ...           ...     ...
# 3192  [{'system': 'GDC', 'value': 'HTMCP-03-06-02210'}]  homo sapiens  female
# 3193  [{'system': 'GDC', 'value': 'GENIE-DFCI-007248'}]  homo sapiens  female
# 3194  [{'system': 'GDC', 'value': 'GENIE-DFCI-000252'}]  homo sapiens  female
# 3195  [{'system': 'GDC', 'value': 'GENIE-MSK-P-00154...  homo sapiens  female
# 3196   [{'system': 'GDC', 'value': 'GENIE-UHN-365307'}]  homo sapiens  female
#
#                            race               ethnicity  days_to_birth  \
# 0                         white  not hispanic or latino       -23010.0
# 1                         white  not hispanic or latino       -26054.0
# 2                         white  not hispanic or latino       -26054.0
# 3                         white  not hispanic or latino       -16071.0
# 4                  not reported            not reported            NaN
# ...                         ...                     ...            ...
# 3192  black or african american                 Unknown            NaN
# 3193                      white  not hispanic or latino       -15340.0
# 3194                      white  not hispanic or latino       -13879.0
# 3195                      white  not hispanic or latino       -30681.0
# 3196                      white  not allowed to collect       -24837.0
#
#      subject_associated_project  vital_status  days_to_death cause_of_death
# 0                  [GENIE-DFCI]  Not Reported            NaN           None
# 1          [TCGA-UCS, tcga_ucs]         Alive            NaN           None
# 2          [TCGA-UCS, tcga_ucs]         Alive            NaN           None
# 3                   [GENIE-MSK]  Not Reported            NaN           None
# 4                       [FM-AD]  Not Reported            NaN           None
# ...                         ...           ...            ...            ...
# 3192            [CGCI-HTMCP-CC]          Dead          183.0        Unknown
# 3193               [GENIE-DFCI]  Not Reported            NaN           None
# 3194               [GENIE-DFCI]  Not Reported            NaN           None
# 3195                [GENIE-MSK]  Not Reported            NaN           None
# 3196                [GENIE-UHN]  Not Reported            NaN           None
#
# [3197 rows x 17 columns]

# %% [markdown]
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# And saves it out to a csv so she can browse it with Excel:

# %%
allmetadata.to_csv("allmetadata.csv")

# %% [markdown]
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# Julia knows from her subject count summary that there are more than 200,000 files associated with her subjects, which is likely far more than she needs. To help her decide what files she wants, Julia uses endpoint chaining to get summary information about the files that are assigned to researchsubjects for her search criteria:

# %%
NoAdenoData.researchsubject.file.count.run()
# Out:
# Getting results from database
# Total execution time: 13151 ms
#    total : 267283
# <style type="text/css">
# #T_736fe_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_736fe_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_736fe_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_736fe_row0_col0" class="data row0 col0" >IDC</td>
#       <td id="T_736fe_row0_col1" class="data row0 col1" >264429</td>
#     </tr>
#     <tr>
#       <td id="T_736fe_row1_col0" class="data row1 col0" >GDC</td>
#       <td id="T_736fe_row1_col1" class="data row1 col1" >294</td>
#     </tr>
#     <tr>
#       <td id="T_736fe_row2_col0" class="data row2 col0" >PDC</td>
#       <td id="T_736fe_row2_col1" class="data row2 col1" >2560</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_74c1b_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_74c1b_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_74c1b_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >data_category</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_74c1b_row0_col0" class="data row0 col0" >Imaging</td>
#       <td id="T_74c1b_row0_col1" class="data row0 col1" >264429</td>
#     </tr>
#     <tr>
#       <td id="T_74c1b_row1_col0" class="data row1 col0" >Raw Mass Spectra</td>
#       <td id="T_74c1b_row1_col1" class="data row1 col1" >640</td>
#     </tr>
#     <tr>
#       <td id="T_74c1b_row2_col0" class="data row2 col0" >Peptide Spectral Matches</td>
#       <td id="T_74c1b_row2_col1" class="data row2 col1" >1280</td>
#     </tr>
#     <tr>
#       <td id="T_74c1b_row3_col0" class="data row3 col0" >Processed Mass Spectra</td>
#       <td id="T_74c1b_row3_col1" class="data row3 col1" >640</td>
#     </tr>
#     <tr>
#       <td id="T_74c1b_row4_col0" class="data row4 col0" >Simple Nucleotide Variation</td>
#       <td id="T_74c1b_row4_col1" class="data row4 col1" >114</td>
#     </tr>
#     <tr>
#       <td id="T_74c1b_row5_col0" class="data row5 col0" >Somatic Structural Variation</td>
#       <td id="T_74c1b_row5_col1" class="data row5 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_74c1b_row6_col0" class="data row6 col0" >Copy Number Variation</td>
#       <td id="T_74c1b_row6_col1" class="data row6 col1" >37</td>
#     </tr>
#     <tr>
#       <td id="T_74c1b_row7_col0" class="data row7 col0" >Transcriptome Profiling</td>
#       <td id="T_74c1b_row7_col1" class="data row7 col1" >31</td>
#     </tr>
#     <tr>
#       <td id="T_74c1b_row8_col0" class="data row8 col0" >Biospecimen</td>
#       <td id="T_74c1b_row8_col1" class="data row8 col1" >17</td>
#     </tr>
#     <tr>
#       <td id="T_74c1b_row9_col0" class="data row9 col0" >Structural Variation</td>
#       <td id="T_74c1b_row9_col1" class="data row9 col1" >29</td>
#     </tr>
#     <tr>
#       <td id="T_74c1b_row10_col0" class="data row10 col0" >Clinical</td>
#       <td id="T_74c1b_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_74c1b_row11_col0" class="data row11 col0" >DNA Methylation</td>
#       <td id="T_74c1b_row11_col1" class="data row11 col1" >24</td>
#     </tr>
#     <tr>
#       <td id="T_74c1b_row12_col0" class="data row12 col0" >Sequencing Reads</td>
#       <td id="T_74c1b_row12_col1" class="data row12 col1" >35</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4bfb1_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_4bfb1_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_4bfb1_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >file_format</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4bfb1_row0_col0" class="data row0 col0" >DICOM</td>
#       <td id="T_4bfb1_row0_col1" class="data row0 col1" >264429</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row1_col0" class="data row1 col0" >TSV</td>
#       <td id="T_4bfb1_row1_col1" class="data row1 col1" >39</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row2_col0" class="data row2 col0" >tsv</td>
#       <td id="T_4bfb1_row2_col1" class="data row2 col1" >640</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row3_col0" class="data row3 col0" >vendor-specific</td>
#       <td id="T_4bfb1_row3_col1" class="data row3 col1" >640</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row4_col0" class="data row4 col0" >BAM</td>
#       <td id="T_4bfb1_row4_col1" class="data row4 col1" >35</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row5_col0" class="data row5 col0" >mzML</td>
#       <td id="T_4bfb1_row5_col1" class="data row5 col1" >640</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row6_col0" class="data row6 col0" >BEDPE</td>
#       <td id="T_4bfb1_row6_col1" class="data row6 col1" >19</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row7_col0" class="data row7 col0" >mzIdentML</td>
#       <td id="T_4bfb1_row7_col1" class="data row7 col1" >640</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row8_col0" class="data row8 col0" >VCF</td>
#       <td id="T_4bfb1_row8_col1" class="data row8 col1" >61</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row9_col0" class="data row9 col0" >TXT</td>
#       <td id="T_4bfb1_row9_col1" class="data row9 col1" >50</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row10_col0" class="data row10 col0" >MAF</td>
#       <td id="T_4bfb1_row10_col1" class="data row10 col1" >54</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row11_col0" class="data row11 col0" >IDAT</td>
#       <td id="T_4bfb1_row11_col1" class="data row11 col1" >16</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row12_col0" class="data row12 col0" >SVS</td>
#       <td id="T_4bfb1_row12_col1" class="data row12 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row13_col0" class="data row13 col0" >BCR Auxiliary XML</td>
#       <td id="T_4bfb1_row13_col1" class="data row13 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row14_col0" class="data row14 col0" >BCR XML</td>
#       <td id="T_4bfb1_row14_col1" class="data row14 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row15_col0" class="data row15 col0" >BCR SSF XML</td>
#       <td id="T_4bfb1_row15_col1" class="data row15 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_4bfb1_row16_col0" class="data row16 col0" >BCR PPS XML</td>
#       <td id="T_4bfb1_row16_col1" class="data row16 col1" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_dd7ee_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_dd7ee_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_dd7ee_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >data_type</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dd7ee_row0_col0" class="data row0 col0" >None</td>
#       <td id="T_dd7ee_row0_col1" class="data row0 col1" >264429</td>
#     </tr>
#     <tr>
#       <td id="T_dd7ee_row1_col0" class="data row1 col0" >Text</td>
#       <td id="T_dd7ee_row1_col1" class="data row1 col1" >640</td>
#     </tr>
#     <tr>
#       <td id="T_dd7ee_row2_col0" class="data row2 col0" >Open Standard</td>
#       <td id="T_dd7ee_row2_col1" class="data row2 col1" >1280</td>
#     </tr>
#     <tr>
#       <td id="T_dd7ee_row3_col0" class="data row3 col0" >Proprietary</td>
#       <td id="T_dd7ee_row3_col1" class="data row3 col1" >640</td>
#     </tr>
#     <tr>
#       <td id="T_dd7ee_row4_col0" class="data row4 col0" >Aligned Reads</td>
#       <td id="T_dd7ee_row4_col1" class="data row4 col1" >35</td>
#     </tr>
#     <tr>
#       <td id="T_dd7ee_row5_col0" class="data row5 col0" >Copy Number Segment</td>
#       <td id="T_dd7ee_row5_col1" class="data row5 col1" >11</td>
#     </tr>
#     <tr>
#       <td id="T_dd7ee_row6_col0" class="data row6 col0" >Annotated Somatic Mutation</td>
#       <td id="T_dd7ee_row6_col1" class="data row6

# %% [markdown]
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# Julia decides that a good place to start would be with Slide Images. There's only 1111, so she should be able to quickly scan through them over the next few days and see if they will be useful. So she adds one more filter on her search:

# %%
JustSlides = Q('file.data_type = "Slide Image"')
NoadenoJustSlides = NoAdenoData.AND(JustSlides)
NoadenoJustSlides.researchsubject.file.count.run()
# Out:
# Getting results from database
# Total execution time: 7349 ms
#      total : 8
# <style type="text/css">
# #T_d9a3e_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_d9a3e_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_d9a3e_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >system</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d9a3e_row0_col0" class="data row0 col0" >GDC</td>
#       <td id="T_d9a3e_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0715b_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_0715b_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_0715b_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >data_category</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0715b_row0_col0" class="data row0 col0" >Biospecimen</td>
#       <td id="T_0715b_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8f212_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_8f212_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_8f212_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >file_format</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8f212_row0_col0" class="data row0 col0" >SVS</td>
#       <td id="T_8f212_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b72a2_ th {
#   background-color: #000066;
#   color: white;
#   text-align: left;
# }
# #T_b72a2_ td {
#   text-align: left;
#   border-bottom: 1px solid black;
# }
# </style>
# <table id="T_b72a2_" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >data_type</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b72a2_row0_col0" class="data row0 col0" >Slide Image</td>
#       <td id="T_b72a2_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# Finally, Julia uses the pagenation function again to get all the slide files, and merges her metadata file with this file information. This way she will be able to review what phenotypes each slide is associated with:

# %%
slides = NoadenoJustSlides.researchsubject.file.run()
slidesdf = pd.DataFrame()
for i in slides.paginator(to_df=True):
    slidesdf = pd.concat([slidesdf, i])
# Out:
# Getting results from database
# Total execution time: 7162 ms

# %%
slidemetadata = pd.merge(slidesdf, 
                         allmetadata, 
                         on="subject_id")
slidemetadata
# Out:
#                                       id  \
# 0   002a60d4-280c-44b5-a0bf-5e2f063253b2
# 1   002a60d4-280c-44b5-a0bf-5e2f063253b2
# 2   016cff56-c7a4-462b-8a84-12d112a90739
# 3   016cff56-c7a4-462b-8a84-12d112a90739
# 4   01e9b85a-e6c7-4117-9bfd-86050f5a2ff7
# 5   00d9d6d3-07af-41f8-bf84-4f2bf200461d
# 6   00d9d6d3-07af-41f8-bf84-4f2bf200461d
# 7   00af722b-dd64-4909-92fa-27116bd2d728
# 8   00af722b-dd64-4909-92fa-27116bd2d728
# 9   02739e88-15df-4e7b-ac86-c0e2931bf713
# 10  02739e88-15df-4e7b-ac86-c0e2931bf713
# 11  0261cb79-9879-480a-9626-63fd50d6daea
# 12  0261cb79-9879-480a-9626-63fd50d6daea
# 13  01f8a923-19c7-43c4-b337-fca47fda7a0c
# 14  01f8a923-19c7-43c4-b337-fca47fda7a0c
#
#                                            identifier  \
# 0   [{'system': 'GDC', 'value': '002a60d4-280c-44b...
# 1   [{'system': 'GDC', 'value': '002a60d4-280c-44b...
# 2   [{'system': 'GDC', 'value': '016cff56-c7a4-462...
# 3   [{'system': 'GDC', 'value': '016cff56-c7a4-462...
# 4   [{'system': 'GDC', 'value': '01e9b85a-e6c7-411...
# 5   [{'system': 'GDC', 'value': '00d9d6d3-07af-41f...
# 6   [{'system': 'GDC', 'value': '00d9d6d3-07af-41f...
# 7   [{'system': 'GDC', 'value': '00af722b-dd64-490...
# 8   [{'system': 'GDC', 'value': '00af722b-dd64-490...
# 9   [{'system': 'GDC', 'value': '02739e88-15df-4e7...
# 10  [{'system': 'GDC', 'value': '02739e88-15df-4e7...
# 11  [{'system': 'GDC', 'value': '0261cb79-9879-480...
# 12  [{'system': 'GDC', 'value': '0261cb79-9879-480...
# 13  [{'system': 'GDC', 'value': '01f8a923-19c7-43c...
# 14  [{'system': 'GDC', 'value': '01f8a923-19c7-43c...
#
#                                                 label data_category  \
# 0   TCGA-EA-A6QX-01A-01-TSA.66853F14-1300-4D44-B29...   Biospecimen
# 1   TCGA-EA-A6QX-01A-01-TSA.66853F14-1300-4D44-B29...   Biospecimen
# 2   TCGA-EK-A2H1-01A-01-TSA.B0EA350D-B3CA-482F-AC0...   Biospecimen
# 3   TCGA-EK-A2H1-01A-01-TSA.B0EA350D-B3CA-482F-AC0...   Biospecimen
# 4   TCGA-IW-A3M4-01Z-00-DX1.03BE04CC-552B-40E8-85D...   Biospecimen
# 5   TCGA-AX-A2H5-11A-01-TSA.6a778f9f-2717-4bb8-83d...   Biospecimen
# 6   TCGA-AX-A2H5-11A-01-TSA.6a778f9f-2717-4bb8-83d...   Biospecimen
# 7   TCGA-FU-A3HZ-01Z-00-DX1.1E78D8EF-B1FF-49AC-9EC...   Biospecimen
# 8   TCGA-FU-A3HZ-01Z-00-DX1.1E78D8EF-B1FF-49AC-9EC...   Biospecimen
# 9   TCGA-VS-A9UL-01Z-00-DX1.4348D92F-0EA0-4A98-8F5...   Biospecimen
# 10  TCGA-VS-A9UL-01Z-00-DX1.4348D92F-0EA0-4A98-8F5...   Biospecimen
# 11  TCGA-VS-A9UP-01A-01-TS1.68E82753-9B6E-4544-B91...   Biospecimen
# 12  TCGA-VS-A9UP-01A-01-TS1.68E82753-9B6E-4544-B91...   Biospecimen
# 13  TCGA-B5-A0JN-01A-01-BS1.19bbff7a-2913-4963-8bb...   Biospecimen
# 14  TCGA-B5-A0JN-01A-01-BS1.19bbff7a-2913-4963-8bb...   Biospecimen
#
#       data_type file_format associated_project  \
# 0   Slide Image         SVS          TCGA-CESC
# 1   Slide Image         SVS          TCGA-CESC
# 2   Slide Image         SVS          TCGA-CESC
# 3   Slide Image         SVS          TCGA-CESC
# 4   Slide Image         SVS          TCGA-SARC
# 5   Slide Image         SVS          TCGA-UCEC
# 6   Slide Image         SVS          TCGA-UCEC
# 7   Slide Image         SVS          TCGA-CESC
# 8   Slide Image         SVS          TCGA-CESC
# 9   Slide Image         SVS          TCGA-CESC
# 10  Slide Image         SVS          TCGA-CESC
# 11  Slide Image         SVS          TCGA-CESC
# 12  Slide Image         SVS          TCGA-CESC
# 13  Slide Image         SVS          TCGA-UCEC
# 14  Slide Image         SVS          TCGA-UCEC
#
#                                               drs_uri   byte_size  \
# 0   drs://dg.4DFC:002a60d4-280c-44b5-a0bf-5e2f0632...   256639621
# 1   drs://dg.4DFC:002a60d4-280c-44b5-a0bf-5e2f0632...   256639621
# 2   drs://dg.4DFC:016cff56-c7a4-462b-8a84-12d112a9...   133766513
# 3   drs://dg.4DFC:016cff56-c7a4-462b-8a84-12d112a9...   133766513
# 4   drs://dg.4DFC:01e9b85a-e6c7-4117-9bfd-86050f5a...  2303418723
# 5   drs://dg.4DFC:00d9d6d3-07af-41f8-bf84-4f2bf200...    56262805
# 6   drs://dg.4DFC:00d9d6d3-07af-41f8-bf84-4f2bf200...    56262805
# 7   drs://dg.4DFC:00af722b-dd64-4909-92fa-27116bd2...   538854312
# 8   drs://dg.4DFC:00af722b-dd64-4909-92fa-27116bd2...   538854312
# 9   drs://dg.4DFC:02739e88-15df-4e7b-ac86-c0e2931b...   341653835
# 10  drs://dg.4DFC:02739e88-15df-4e7b-ac86-c0e2931b...   341653835
# 11  drs://dg.4DFC:0261cb79-9879-480a-9626-63fd50d6...   201483703
# 12  drs://dg.4DFC:0261cb79-9879-480a-9626-63fd50d6...   201483703
# 13  drs://dg.4DFC:01f8a923-19c7-43c4-b337-fca47fda...   329775631
# 14  drs://dg.4DFC:01f8a923-19c7-43c4-b337-fca47fda...   329775631
#
#                             checksum  ...  \
# 0   c937af221666a0be405b665631582b32  ...
# 1   c937af221666a0be405b665631582b32  ...
# 2   ec96548913e8060f75db0c867bb00336  ...
# 3   ec96548913e8060f75db0c867bb00336  ...
# 4   6ef35302e17fdb5f712c0ece967ad543  ...
# 5   58733b0552dc9dde57605e4215550b51  ...
# 6   58733b0552dc9dde57605e4215550b51  ...
# 7   1a799ba38252a841393ef5aab4f87764  ...
# 8   1a799ba38252a841393ef5aab4f87764  ...
# 9   0c506efa82b701b2ef0f3bba8b275db0  ...
# 10  0c506efa82b701b2ef0f3bba8b275db0  ...
# 11  8318b25bce4cc03960bdbca1112c520b  ...
# 12  8318b25bce4cc03960bdbca1112c520b  ...
# 13  463372cea1072caab6e8b21f3408575c  ...
# 14  463372cea1072caab6e8b21f3408575c  ...
#
#                                          identifier_y       species     sex  \
# 0   [{'system': 'GDC', 'value': 'TCGA-EA-A6QX'}, {...  homo sapiens  female
# 1   [{'system': 'GDC', 'value': 'TCGA-EA-A6QX'}, {...  homo sapiens  female
# 2   [{'system': 'GDC', 'value': 'TCGA-EK-A2H1'}, {...  homo sapiens  female
# 3   [{'system': 'GDC', 'value': 'TCGA-EK-A2H1'}, {...  homo sapiens  female
# 4   [{'system': 'GDC', 'value': 'TCGA-IW-A3M4'}, {...  homo sapiens  female
# 5   [{'system': 'GDC', 'value': 'TCGA-AX-A2H5'}, {...  homo sapiens  female
# 6   [{'system': 'GDC', 'value': 'TCGA-AX-A2H5'}, {...  homo sapiens  female
# 7   [{'system': 'GDC', 'value': 'TCGA-FU-A3HZ'}, {...  homo sapiens  female
# 8   [{'system': 'GDC', 'value': 'TCGA-FU-A3HZ'}, {...  homo sapiens  female
# 9   [{'system': 'GDC', 'value': 'TCGA-VS-A9UL'}, {...  homo sapiens  female
# 10  [{'system': 'GDC', 'value': 'TCGA-VS-A9UL'}, {...  homo sapiens  female
# 11  [{'system': 'GDC', 'value': 'TCGA-VS-A9UP'}, {...  homo sapiens  female
# 12  [{'system': 'GDC', 'value': 'TCGA-VS-A9UP'}, {...  homo sapiens  female
# 13  [{'system': 'GDC', 'value': 'TCGA-B5-A0JN'}, {...  homo sapiens  female
# 14  [{'system': 'GDC', 'value': 'TCGA-B5-A0JN'}, {...  homo sapiens  female
#
#                          race               ethnicity days_to_birth  \
# 0                       asian  not hispanic or latino      -18035.0
# 1                       asian  not hispanic or latino      -18035.0
# 2                       white            not reported       -7649.0
# 3                       white            not reported       -7649.0
# 4                       white  not hispanic or latino      -17721.0
# 5   black or african american  not hispanic or latino      -24757.0
# 6   black or african american  not hispanic or latino      -24757.0
# 7                       white  not hispanic or latino      -23565.0
# 8                       white  not hispanic or latino      -23565.0
# 9                       white            not reported      -29033.0
# 10                      white            not reported      -29033.0
# 11               not reported            not reported      -15849.0
# 12               not reported            not reported      -15849.0
# 13  black or african american            not reported      -30933.0
# 14  black or african american            not reported      -30933.0
#
#    subject_associated_project vital_status days_to_death cause_of_death
# 0      [TCGA-CESC, tcga_cesc]        Alive           NaN           None
# 1      [TCGA-CESC, tcga_cesc]        Alive           NaN           None
# 2      [TCGA-CESC, tcga_cesc]        Alive           NaN           None
# 3      [TCGA-CESC, tcga_cesc]        Alive           NaN           None
# 4      [tcga_sarc, TCGA-SARC]        Alive           NaN           None
# 5      [TCGA-UCEC, tcga_ucec]        Alive           NaN           None
# 6      [TCGA-UCEC, tcga_ucec]        Alive           NaN           None
# 7      [TCGA-CESC, tcga_cesc]        Alive           NaN           None
# 8      [TCGA-CESC, tcga_cesc]        Alive           NaN           None
# 9      [TCGA-CESC, tcga_cesc]         Dead         442.0           None
# 10     [TCGA-CESC, tcga_cesc]         Dead         442.0           None
# 11     [TCGA-CESC, tcga_cesc]        Alive           NaN           None
# 12     [TCGA-CESC, tcga_cesc]        Alive           NaN           None
# 13     [TCGA-UCEC, tcga_ucec]        Alive           NaN           None
# 14     [TCGA-UCEC, tcga_ucec]        Alive           NaN           None
#
# [15 rows x 32 columns]

# %% [markdown]
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# She saves this file out as well.

# %%
slidemetadata.to_csv("slidemetadata.csv")

# %% [markdown]
# <img src="https://github.com/CancerDataAggregator/readthedocs/blob/main/docs/Examples/images/Julia.png?raw=true" align="left"
# 	width="50" height="50" />
#
# Now Julia has all the information she needs to begin work on her project. She can use the `drs_id` column information to directly download the images she is interested in using a DRS resolver, or she can input the DRS IDs at a cloud workspace such as [Terra](https://terra.bio/) or the [Cancer Genomics Cloud](https://www.cancergenomicscloud.org/) to view the images online. In either case, she has all the metadata she needs to get started, and can save this notebook of her work in case she'd like to come back and modify her search.
